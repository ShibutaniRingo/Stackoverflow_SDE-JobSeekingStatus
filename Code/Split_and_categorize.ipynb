# %%
import numpy as np
import pandas as pd
df = pd.read_csv('dummied_basic_features.csv',index_col=0)
df
# Out:
# /Users/jizngziwei/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (3,4,5,6,7,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                                  DevType  JobSatisfaction  \
# 0                                   Full-stack developer              6.0
# 1      Database administrator;DevOps specialist;Full-...              1.0
# 2               Engineering manager;Full-stack developer              5.0
# 3                                   Full-stack developer              3.0
# 4      Data or business analyst;Desktop or enterprise...              4.0
# 5      Back-end developer;Database administrator;Fron...              5.0
# 6      Back-end developer;Front-end developer;Full-st...              4.0
# 7      Designer;Front-end developer;QA or test developer              4.0
# ...

# %%
import re
